# %%
import pandas as pd

# %%
file = pd.read_parquet("https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2022-03.parquet")
file.to_parquet("green_tripdata_2021-03.parquet")

# %%
import mlflow

# %%
mlflow.__version__
# Out:
# '1.26.1'
